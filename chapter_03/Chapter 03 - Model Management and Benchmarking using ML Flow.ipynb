# %% [markdown]
# # Chapter 03 - Model Management and Benchmarking using MLflow

# %%
# Python version 3.9.21
# !python --version
# Out:
# Python 3.9.21

# %% [markdown]
# ## Listing 3-1. Installing and importing MLflow

# %%
import mlflow

# %% [markdown]
# ## Listing 3-2. The model code

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression

def train_and_predict_model():
    
    # get the famous diabetes dataset through sklearn
    X, y = load_diabetes(return_X_y=True)

    # instantiate a linear regression model
    linear_model = LinearRegression()

    # fit the model on the diabetes data
    linear_model.fit(X, y)

    # predict on the training data
    preds = linear_model.predict(X)

# %% [markdown]
# ## Listing 3-3. MLflow autologging

# %%
# Start mlflow auto logging
mlflow.autolog()

# Call the model training function
train_and_predict_model()
# Out:
# 2025/08/15 12:10:32 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/08/15 12:10:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f724ea0515844ff9ac56efdc8a9a26e4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %% [markdown]
# ## Listing 3-5. Setting a tag

# %%
# Start mlflow auto logging
mlflow.autolog(
    extra_tags={"code_listing": "3-5"},
)

# Call the model training function
train_and_predict_model()
# Out:
# 2025/08/15 12:10:34 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/08/15 12:10:34 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'c1f79fb52d14422f8e1c081d74def862', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %% [markdown]
# ## Listing 3-6. Retreiving the information

# %%
# Specify the path to the model and run that you want to load
model_path = 'mlruns/0/0fce5bdc8b204dfaa43fdd42f48c5d26/artifacts/model'

# Load the mode;l 
loaded_model = mlflow.sklearn.load_model(model_path)

# Use the model, in this case for example for making a prediction on the diabetes data
X, y = load_diabetes(return_X_y=True)
loaded_model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 5
#       2 model_path = 'mlruns/0/0fce5bdc8b204dfaa43fdd42f48c5d26/artifacts/model'
#       4 # Load the mode;l
# ----> 5 loaded_model = mlflow.sklearn.load_model(model_path)
#       7 # Use the model, in this case for example for making a prediction on the diabetes data
#       8 X, y = load_diabetes(return_X_y=True)
#
# File /opt/anaconda3/envs/chapter3-v2/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:633, in load_model(model_uri, dst_path)
#     598 def load_model(model_uri, dst_path=None):
#     599     """
#     600     Load a scikit-learn model from a local file or a run.
#     601
#    (...)
#     631         predictions = sk_model.predict(pandas_df)
#     632     """
# --> 633     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     634     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
#     635     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File /opt/anaconda3/envs/chapter3-v2/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py:116, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
# --> 116 return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#
# File /opt/anaconda3/envs/chapter3-v2/lib/python3.9/site-packages/mlflow/store/artifact/local_artifact_repo.py:91, in LocalArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#      89 local_artifact_path = os.path.join(self.artifact_dir, os.path.normpath(artifact_path))
#      90 if not os.path.exists(local_artifact_path):
# ---> 91     raise OSError(f"No such file or directory: '{local_artifact_path}'")
#      92 return os.path.abspath(local_artifact_path)
#
# OSError: No such file or directory: 'mlruns/0/0fce5bdc8b204dfaa43fdd42f48c5d26/artifacts/model'

# %% [markdown]
# ## Listing 3-7. Start the MLFlow UI

# %%
# !mlflow ui --port 8080
